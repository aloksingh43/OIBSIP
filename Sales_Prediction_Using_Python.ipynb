# %% [markdown]
# <a href="https://colab.research.google.com/github/aloksingh43/OIBSIP/blob/main/Sales_Prediction_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Oasis Infobyte**

# %% [markdown]
# # **PROJECT NAME-**
# ## **Sales Prediction Using Python**

# %% [markdown]
# ![Screenshot 2023-04-09 184600.png](data:image/png;base64,...)

# %% [markdown]
# Batch - **March Phase 2 OIBSIP**
#
# Author : **Alok Singh**
#
# Task 2 : **Sales Prediction Using Python**
#
# Language :**Python**
#
# IDE : **google colab**
#
# Github Link : https://github.com/aloksingh43/OIBSIP

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing the dataset
df=pd.read_csv('/content/drive/MyDrive/Oasis_Infobyte /Advertising.csv')

# %% [markdown]
# ### **Data Inspection**

# %%
# First look
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.size
# Out:
# 1000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# #Null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    200
# dtype: int64

# %% [markdown]
# ### **correlation plot**

# %%
correlation=df.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Pair plot**

# %%
#plot pair plot
sns.pairplot(df)

# %% [markdown]
# ### **Data Modelling**

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X =np.array(df.drop(['Sales'], 1))
y =np.array(df['Sales'])
# Out:
# <ipython-input-18-0f5fb5e6cf60>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X =np.array(df.drop(['Sales'], 1))

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y,train_size=0.8,test_size=0.2,random_state=0)

# %% [markdown]
# ### **Implementing Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = regressor.predict(X_test)
y_predict
# Out:
# array([10.05739563,  7.4522807 ,  7.0197076 , 24.08029725, 12.01786259,
#         6.53793858, 12.78286918, 15.10974587, 10.76974013, 16.34357951,
#        22.88297477,  9.12924467, 10.46455672, 15.48743552, 11.58555633,
#        12.17296914, 18.76551502, 10.78318566, 15.90515992, 17.30651279,
#        24.06692057,  9.59834224, 15.13512211, 12.38591525,  5.71360885,
#        15.24749314, 12.29402334, 20.9421167 , 13.40991558,  9.04348832,
#        12.89239415, 21.40272028, 18.13802209, 21.17320803,  6.56974433,
#         6.14114206,  7.89018394, 13.01541434, 14.68953791,  6.18835143])

# %%
# calculating the coefficient
coefficient = regressor.coef_
coefficient
# Out:
# array([ 0.04458402,  0.19649703, -0.00278146])

# %%
# calculating the intercept
intercept = regressor.intercept_
intercept
# Out:
# 2.994893030495332

# %%
MSE  = mean_squared_error((y_test),(y_predict))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score((y_test), (y_predict))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score((y_test), (y_predict)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# MSE : 4.402118291449685
# RMSE : 2.0981225634956804
# R2 : 0.8601145185017868
# Adjusted R2 :  0.8484573950436023

# %%
plt.figure(figsize=(8,5))
plt.plot((y_predict))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
forecast=pd.DataFrame(data={'Forecasted Sales': y_predict.flatten()})
forecast
# Out:
#     Forecasted Sales
# 0          10.057396
# 1           7.452281
# 2           7.019708
# 3          24.080297
# 4          12.017863
# 5           6.537939
# 6          12.782869
# 7          15.109746
# 8          10.769740
# 9          16.343580
# 10         22.882975
# 11          9.129245
# 12         10.464557
# 13         15.487436
# 14         11.585556
# 15         12.172969
# 16         18.765515
# 17         10.783186
# 18         15.905160
# 19         17.306513
# 20         24.066921
# 21          9.598342
# 22         15.135122
# 23         12.385915
# 24          5.713609
# 25         15.247493
# 26         12.294023
# 27         20.942117
# 28         13.409916
# 29          9.043488
# 30         12.892394
# 31         21.402720
# 32         18.138022
# 33         21.173208
# 34          6.569744
# 35          6.141142
# 36          7.890184
# 37         13.015414
# 38         14.689538
# 39          6.188351
